# %% [markdown]
# # Quenser Qube-Servo 2 modelling
# - $\theta$ = arm angle, $\alpha$ = pendulum angle
# - $\alpha$ = 0 is the upright position, while $\alpha$ = $\pi$ is the starting position

# %% [markdown]
# ## Motor Parameters and variables

# %%
# pendulum parameters
mar = 0.095 #kg actual mass of arm
lar = 0.085 #m actual length of arm
mpr = 0.024 #kg actual mass of pen
lpr = 0.129 #m actual length of pen

# Motor Parameters
V_nom = 18.0       # Nominal input voltage (V)
tau_nom = 22.0/1000     # Nominal torque (mN-m) (Note: Convert to N-m)
omega_nom = 3050   # Nominal speed (RPM)
I_nom = 0.54       # Nominal current (A)
R_m = 8.4          # Terminal resistance (Ohms)
k_t = 0.042        # Torque constant (N-m/A)
k_m = 0.042        # Motor back-emf constant (V/(rad/s))
J_m = 0.000004     # Rotor inertia (kg-m^2)
L_m = 1.16e-3      # Rotor inductance (H)

# %% [markdown]
# ## USeful functions
# - Rotation matrices
# - torque voltage function

# %%
import sympy as sym
import numpy as np
from IPython.display import display #for pretty printing
import csv

# Define the rotation matrices as functions, counterclockwise rotation
# axes system is defined similar to the one used for making the 3d plots
def rotX(th):
    return sym.Matrix([ [1.0,         0.0,          0.0],
                        [0.0, sym.cos(th), -sym.sin(th)],
                        [0.0, sym.sin(th),  sym.cos(th)]])

def rotY(th):
    return sym.Matrix([ [ sym.cos(th), 0.0, sym.sin(th)],
                        [ 0.0,         1.0,         0.0],
                        [-sym.sin(th), 0.0, sym.cos(th)]])

def rotZ(th):
    return sym.Matrix([ [sym.cos(th), -sym.sin(th), 0.0],
                        [sym.sin(th),  sym.cos(th), 0.0],
                        [0.0,    0.0,               1.0]])

def calculate_torque_voltage(i, m):
    # Step 1: Combine the motor's rotor inertia and the arm's inertia
    J_total = value(m.In[1]) + J_m
    
    # Step 2: Calculate the required torque to rotate the arm (from acceleration)
    if i > 1:
        torque = J_total * m.ddq[i, 1]
    else:
        torque = 0  # or some initial value
    
    # Step 3: Calculate the current required for the torque
    current = torque / k_t
    
    # Step 4: Calculate the motor's voltage, including the back-emf term
    if i > 1:
        voltage = current * R_m + k_m * m.dq[i, 1]
    else:
        voltage = 0  # or some initial value
    
    return torque, voltage

# %% [markdown]
# ## Dynamic Model
# - positions
# - velocities
# - energies
# - lagrangian

# %%
# create symbolic variables
# system parameters
X0, Y0, Z0 = sym.symbols(['X0','Y0', 'Z0']) # fixed position of Arm
g = sym.symbols('g')

mH, Lh, InH = sym.symbols(['m_H', 'l_H', 'I_H']) # Hub
mA, La, InA = sym.symbols(['m_A', 'l_A', 'I_A']) # Arm
mP, Lp, InP = sym.symbols(['m_P', 'l_P', 'I_P']) # Pen

# generalized coordinates
th, dth, ddth       = sym.symbols(['\\theta', '\\dot{\\theta}', '\\ddot{\\theta}'])
alph, dalph, ddalph = sym.symbols(['\\alpha', '\\dot{\\alpha}', '\\ddot{\\alpha}'])

q   = sym.Matrix([  [th],  [alph]]) #group into matrices
dq  = sym.Matrix([ [dth], [dalph]])
ddq = sym.Matrix([[ddth],[ddalph]])

display(ddq) #display prints it as cool latex stuff

# Rotation Matrices
R01 = rotZ(th)
R10 = R01.T

R12 = rotX(alph)
R21 = R12.T

R02 = R12*R01
R20 = R02.T

# Positions-----------------------------------------------
##### Arm is at the origin so no need for X0 and Y0
r_Hub_1 = sym.Matrix([0, 0, 0])
r_Hub   = R10*r_Hub_1

r_Arm_1 = sym.Matrix([La*0.5, 0, 0])
r_Arm   = R10*r_Arm_1

r_Pen_2 = sym.Matrix([0, 0, Lp*0.5]) # when alpha = 0 it should be upright which is the case here
r_Pen   = r_Arm*2 + R20*r_Pen_2
display(r_Arm, r_Pen)

# Velocities-------------------------------------------------
## Linear
dr_Arm = sym.simplify(r_Arm.jacobian(q)*dq)
dr_Pen = sym.simplify(r_Pen.jacobian(q)*dq)
dr_Hub = sym.simplify(r_Hub.jacobian(q)*dq)
#display(dr_Arm,dr_Pen)

## Angular
wHub = sym.Matrix([0, 0, dth])
wArm = sym.Matrix([0, 0, dth])
wPen = R12*wArm + sym.Matrix([dalph, 0, 0])

#display(wArm, wPen)

# Energies
## Kinetic energies
Ek = lambda m, dr, w, In: (0.5*m*dr.T*dr) + (0.5*In*w.T*w)
THub = Ek(mH, dr_Hub, wHub, InH)
TArm = sym.simplify(Ek(mA, dr_Arm, wArm, InA))
TPen = sym.simplify(Ek(mP, dr_Pen, wPen, InP))
T = sym.Matrix([sym.simplify(TArm + TPen)])
#display(THub, TArm, TPen, T)

## Potential energies
VArm = 0
VHub = 0
VPen = mP*g*r_Pen[2]
V = sym.Matrix([sym.simplify(VArm + VHub + VPen)])
#display(V)
# Out:
# Matrix([
# [\ddot{\theta}],
# [\ddot{\alpha}]])
# Matrix([
# [ 0.5*l_A*cos(\theta)],
# [-0.5*l_A*sin(\theta)],
# [                   0]])
# Matrix([
# [ 1.0*l_A*cos(\theta) + 0.5*l_P*sin(\alpha)*sin(\theta)],
# [-1.0*l_A*sin(\theta) + 0.5*l_P*sin(\alpha)*cos(\theta)],
# [                                   0.5*l_P*cos(\alpha)]])

# %% [markdown]
# ## Forces, torques and lagrangian

# %%
# forces & torques
tau = sym.symbols('\\tau')
vol   = sym.symbols('V')

Qtau = sym.Matrix([[tau],[0]]) # Torque tau acts in the th1 direction

Qtot = Qtau
Qall = Qtau
# ------------------------------------------------------------------------------------------------------------------
Lg1 = sym.zeros(1,len(q))
for i in range(len(q)):
    dT_ddq = sym.diff(T,dq[i]) # get partial of T in dq_i
    Lg1[i] = dT_ddq.jacobian(q)*dq + dT_ddq.jacobian(dq)*ddq #...then get time derivative of that partial

# term 3
Lg3 = T.jacobian(q) # partial of T in q

# term 4
Lg4 = V.jacobian(q) # partial of U in q

# put it all together
EOM = Lg1 - Lg3 + Lg4 - Qall.transpose()

EOM[1].simplify()
EOM = sym.simplify(EOM)
display(EOM)
# Out:
# Matrix([[-0.5*\ddot{\alpha}*l_A*l_P*m_P*cos(\alpha) + \ddot{\theta}*(I_A + 1.0*I_P + 0.25*l_A**2*m_A + 1.0*l_A**2*m_P + 0.25*l_P**2*m_P*sin(\alpha)**2) + 0.5*\dot{\alpha}*l_P*m_P*(\dot{\alpha}*l_A + \dot{\theta}*l_P*cos(\alpha))*sin(\alpha) - \tau, \ddot{\alpha}*(1.0*I_P + 0.25*l_P**2*m_P) - 0.5*\ddot{\theta}*l_A*l_P*m_P*cos(\alpha) - 0.125*\dot{\theta}**2*l_P**2*m_P*sin(2*\alpha) - 0.5*g*l_P*m_P*sin(\alpha)]])

# %% [markdown]
# # Pyomo stuff

# %%
from pyomo.environ import*
from pyomo.opt import SolverFactory
from pyomo.opt import SolverStatus, TerminationCondition

# Create model
m = ConcreteModel()

# Model parameters
N = 100 # number of points in the trajectory
m.N = RangeSet(N)
m.L = RangeSet(2)

# initialise some parameters
m.g   = Param(initialize = 9.81) # gravity
m.X0  = Param(initialize = 0.00) # Base position
m.Y0  = Param(initialize = 0.00)
m.Z0  = Param(initialize = 0.00)
m.h   = Param(initialize = 0.02) # timestep
m.m   = Param(m.L, initialize={1: 0.095, 2: 0.024})  # mass of links (kg)
m.len = Param(m.L, initialize={1: 0.085, 2: 0.129})  # length of links (m)


# Moment of inertia calculation
calculate_In = lambda m, l: m.m[l]*m.len[l]**2/12
m.In = Param(m.L, initialize = calculate_In) # moment of inertia

# Variables
m.q   = Var(m.N, m.L) # position
m.dq  = Var(m.N, m.L) # velocity
m.ddq = Var(m.N, m.L) # acceleration

# define torque and voltage
m.Tc = Var(m.N) # torque


# Integration constraints---------------------------------
## positions-------------
def BwEuler_p(m,n,l): # for positions
    if n > 1:
        return m.q[n,l] == m.q[n-1,l] + m.h*m.dq[n-1,l]
    else:
        return Constraint.Skip #use this to leave out members of a set that the constraint doesn't apply to

m.integrate_p = Constraint(m.N, m.L, rule = BwEuler_p)

## velocities-------------
def BwEuler_v(m,n,l): # for velocities
    if n==1:
        return m.dq[n, l] == 0
    elif n > 1:
        return m.dq[n,l] == m.dq[n-1,l] + m.h*m.ddq[n-1,l]
    else:
        return Constraint.Skip 

m.integrate_v = Constraint(m.N, m.L, rule = BwEuler_v)

def BwEuler_a(m, n, l):  # for accelerations
    if n == 1 or n == 2:  # First two time steps
        return m.ddq[n, l] == 0  # Set initial accelerations to zero
    else:
        return Constraint.Skip  # Or define based on dynamics if needed

m.integrate_a = Constraint(m.N, m.L, rule = BwEuler_a)



func_map = {'sin':sin, 'cos':cos}

sym_list = [g,
            mA , mP,
            La , Lp,
            InA,InP,
            X0, Y0, Z0,
            th  ,   alph,
            dth ,  dalph,
            ddth, ddalph,
            tau]

lambEOM = {}
for i in range(1,3):
    lambEOM[i] = sym.lambdify(sym_list, EOM[i-1], modules = [func_map])

def dynamics(m, n, l):
    var_list = [m.g,
            m.m[1] , m.m[2],
            m.len[1] , m.len[2],
            m.In[1]  , m.In[2],
            m.X0, m.Y0, m.Z0,
            m.q[n, 1]   ,    m.q[n, 2],
            m.dq[n, 1]  ,   m.dq[n, 2],
            m.ddq[n, 1] ,  m.ddq[n, 2],
            m.Tc[n]]
    return lambEOM[l](*var_list) == 0
m.dynamics = Constraint(m.N, m.L, rule = dynamics)

# motor model-------------------------------------
## add motor model here

# %%
# Cost function
def CostFun(m):
    torque_sum = sum(m.Tc[n]**2 for n in m.N)
    return torque_sum

m.Cost = Objective(rule = CostFun)


# Variable bounds-----------------------
AB = np.pi/2 # arm angle bounds
PB = np.pi   # pen angle bounds

bounds = {1: (-AB, AB),
          2: (-PB, PB)}

for n in range(1, N+1):
    m.Tc[n].setlb(-0.008)
    m.Tc[n].setub( 0.008)
    for link, (lb, ub) in bounds.items():
        m.q[n, link].setlb(lb)
        m.q[n, link].setub(ub)

# Conditions-------------------------------
## Initial conditions
m.q[1, 1].fix(0)
m.q[1, 2].fix(np.pi)
# m.dq[1, 1].fix(0)
# m.dq[1, 2].fix(0)

## final conditions
m.q[N, 1].fix(0) # final position in the middle
m.q[N, 2].fix(0) # final angle position (upright)
m.dq[N, 1].fix(0)    # final speed (0)
m.dq[N, 2].fix(0)    # final acceleration (0)

# %%
# solving
opt = SolverFactory('ipopt') # standard issue, garden variety ipopt

# If you've managed to install your own version of ipopt, you can call it like:
#opt = SolverFactory('ipopt',executable = 'C:/cygwin64/home/Stacey/CoinIpopt/build/bin/ipopt.exe')
#opt.options["linear_solver"] = 'ma86'

# solver options
opt.options["print_level"]  = 5 # prints a log with each iteration (you want to this - it's the only way to see progress.)
opt.options["max_iter"]     = 30000 # maximum number of iterations
opt.options["max_cpu_time"] = 300 # maximum cpu time in seconds
opt.options["Tol"]          = 1e-6 # the tolerance for feasibility. Considers constraints satisfied when they're within this margin.
    
results = opt.solve(m, tee = True)
# Out:
# Ipopt 3.14.13: print_level=5
# max_iter=30000
# max_cpu_time=300
# Tol=1e-06
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.13, running with linear solver MUMPS 5.2.1.
#
# Number of nonzeros in equality constraint Jacobian...:     2181
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      887
#
# Total number of variables............................:      694
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:      296
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      602
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 3.14e+00 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.0756962e-04 3.12e+00 3.05e-01  -1.0 3.15e+03    -  8.63e-03 7.85e-03h  1
#    2  2.2763111e-04 3.10e+00 5.70e+00  -1.0 3.28e+03    -  1.21e-02 4.61e-03h  1
#    3  3.6577113e-04 3.09e+00 1.42e+01  -1.0 3.62e+03    -  9.43e-03 4.31e-03h  1
#    4  4.9590371e-04 3.08e+00 4.22e+01  -1.0 5.65e+03    -  1.22e-02 3.27e-03h  1
#    5  6.6934946e-04 3.07e+00 1.08e+02  -1.0 8.35e+03    -  1.72e-02 3.67e-03h  1
#    6  6.6760796e-04 3.06e+00 1.12e+02  -1.0 6.75e+03    -  1.38e-03 1.22e-03h  1
#    7  8.6608064e-04 3.05e+00 1.14e+02  -1.0 9.80e+03    -  3.61e-03 3.37e-03h  1
#    8  8.6747661e-04 3.05e+00 1.81e+02  -1.0 5.24e+03    -  1.25e-03 1.48e-04h  1
#    9  1.1210236e-03 3.04e+00 1.21e+02  -1.0 1.19e+04    -  8.14e-04 3.63e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  1.1247193e-03 3.04e+00 2.29e+02  -1.0 6.33e+03    -  1.31e-03 6.66e-05h  1
#   11  1.3889666e-03 3.03e+00 1.14e+02  -1.0 1.43e+04    -  3.70e-04 3.04e-03h  1
#   12  1.4178629e-03 3.03e+00 3.95e+02  -1.0 1.30e+04    -  4.23e-03 2.43e-04h  1
#   13  1.4054564e-03 3.03e+00 3.81e+02  -1.0 1.03e+04    -  2.56e-04 2.93e-04h  1
#   14  1.5940328e-03 3.02e+00 2.20e+02  -1.0 1.66e+04    -  4.17e-04 2.05e-03h  1
#   15  1.6952648e-03 3.02e+00 4.56e+02  -1.0 1.60e+04    -  2.52e-03 6.92e-04h  1
#   16  1.6946770e-03 3.02e+00 6.88e+02  -1.0 1.11e+04    -  2.95e-04 2.99e-05h  1
#   17  1.8153655e-03 3.02e+00 3.73e+02  -1.0 1.91e+04    -  1.22e-04 1.48e-03h  1
#   18  1.9107063e-03 3.02e+00 6.21e+02  -1.0 1.88e+04    -  1.62e-03 6.93e-04h  1
#   19  1.9706234e-03 3.01e+00 9.22e+02  -1.0 2.01e+04    -  1.29e-03 3.99e-04h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  1.9697290e-03 3.01e+00 1.31e+03  -1.0 9.57e+03    -  2.13e-04 2.75e-05h  1
#   21  2.0990319e-03 3.01e+00 6.22e+02  -1.0 2.12e+04    -  6.11e-05 1.31e-03h  1
#   22  2.1618754e-03 3.01e+00 9.07e+02  -1.0 2.56e+04    -  1.02e-03 5.54e-04h  1
#   23  2.2504659e-03 3.01e+00 1.22e+03  -1.0 2.33e+04    -  9.57e-04 5.05e-04h  1
#   24  2.2509335e-03 3.01e+00 2.10e+03  -1.0 8.59e+03    -  3.66e-04 1.48e-05h  1
#   25  2.3169291e-03 3.00e+00 9.54e+02  -1.0 2.09e+04    -  3.23e-05 9.78e-04h  1
#   26  2.3753397e-03 3.00e+00 1.75e+03  -1.0 2.11e+04    -  1.16e-03 4.75e-04h  1
#   27  2.5022702e-03 3.00e+00 2.41e+03  -1.0 2.89e+04    -  1.21e-03 7.20e-04h  1
#   28  2.5483686e-03 3.00e+00 4.27e+03  -1.0 2.95e+04    -  1.48e-03 3.22e-04h  1
#   29  2.5481258e-03 3.00e+00 6.14e+03  -1.0 3.57e+03    -  5.45e-04 4.04e-05h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  2.6089286e-03 3.00e+00 2.98e+03  -1.0 2.36e+04    -  2.69e-05 1.32e-03h  1
#   31  2.6240591e-03 2.99e+00 3.66e+03  -1.0 1.83e+04    -  9.62e-04 6.64e-04h  1
#   32  2.7310782e-03 2.99e+00 6.07e+03  -1.0 2.07e+04    -  1.94e-03 9.57e-04h  1
#   33  2.8285039e-03 2.99e+00 1.28e+04  -1.0 2.01e+04    -  3.55e-03 1.06e-03h  1
#   34  2.8287453e-03 2.99e+00 2.28e+04  -1.0 5.65e+03    -  2.83e-03 4.14e-05h  1
#   35  2.8504298e-03 2.97e+00 5.30e+03  -1.0 6.58e+03    -  4.88e-05 5.06e-03h  1
#   36  2.9135327e-03 2.96e+00 2.09e+03  -1.0 4.90e+03    -  3.58e-03 5.77e-03h  1
#   37  2.9036409e-03 2.93e+00 4.58e+04  -1.0 9.67e+02    -  2.16e-02 8.00e-03h  1
#   38  2.8326574e-03 2.91e+00 4.99e+04  -1.0 1.65e+03    -  7.34e-03 6.12e-03f  1
#   39  2.7964402e-03 2.91e+00 4.82e+04  -1.0 1.35e+03    -  2.68e-03 3.11e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40  2.6187088e-03 2.87e+00 1.98e+04  -1.0 9.66e+02    -  5.31e-03 1.35e-02f  1
#   41  2.5757157e-03 2.85e+00 1.21e+04  -1.0 3.61e+03    -  2.44e-03 4.78e-03h  1
#   42  2.5857301e-03 2.84e+00 5.96e+03  -1.0 5.78e+03    -  2.91e-03 4.80e-03f  1
#   43  2.5152479e-03 2.82e+00 2.10e+03  -1.0 3.06e+03    -  3.93e-03 6.48e-03f  1
#   44  2.5029128e-03 2.78e+00 3.50e+04  -1.0 1.88e+03    -  5.18e-03 1.59e-02h  1
#   45  2.4928747e-03 2.77e+00 3.69e+03  -1.0 9.98e+02    -  1.30e-02 1.99e-03h  1
#   46  2.4477589e-03 2.75e+00 4.59e+02  -1.0 6.04e+02    -  8.43e-03 7.13e-03f  1
#   47  2.4462761e-03 2.75e+00 2.98e+03  -1.0 4.34e+02    -  6.72e-04 1.89e-03h  1
#   48  2.4197502e-03 2.65e+00 8.85e+04  -1.0 4.69e+02    -  1.51e-03 3.42e-02h  1
#   49  2.4196499e-03 2.65e+00 6.82e+04  -1.0 3.37e+02    -  7.75e-02 4.46e-04h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50  2.4097850e-03 2.65e+00 7.81e+04  -1.0 6.28e+02    -  1.21e-02 1.37e-03h  1
#   51  2.3053632e-03 2.57e+00 4.50e+04  -1.0 4.56e+02    -  1.54e-04 2.91e-02h  1
#   52  2.2505132e-03 2.47e+00 1.99e+05  -1.0 2.47e+02    -  1.69e-01 4.01e-02h  1
#   53  2.2472769e-03 2.46e+00 1.97e+05  -1.0 2.00e+02    -  1.19e-02 4.20e-03h  1
#   54  2.2584986e-03 1.77e+00 1.27e+05  -1.0 1.98e+02    -  4.70e-04 2.80e-01h  1
#   55  2.2837011e-03 1.68e+00 2.70e+05  -1.0 6.20e+02    -  1.47e-02 5.08e-02h  1
#   56  2.2852791e-03 1.68e+00 1.51e+05  -1.0 5.47e+02    -  1.02e-01 5.50e-04h  1
#   57  2.2853897e-03 1.67e+00 1.53e+05  -1.0 1.34e+02    -  5.07e-03 3.79e-03h  1
#   58  2.2657004e-03 1.63e+00 9.13e+04  -1.0 2.29e+02    -  7.28e-05 2.36e-02f  1
#   59  2.2651010e-03 1.63e+00 1.58e+05  -1.0 6.60e+02    -  1.76e-02 2.09e-04h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   60  2.2517374e-03 1.63e+00 1.46e+05  -1.0 6.09e+02    -  2.03e-04 3.48e-03f  1
#   61  2.2471148e-03 1.63e+00 1.46e+05  -1.0 1.05e+03    -  5.11e-05 4.50e-04h  1
#   62  2.2404584e-03 1.63e+00 1.47e+05  -1.0 1.06e+03    -  2.15e-03 6.49e-04h  1
#   63  2.1600688e-03 1.61e+00 1.41e+05  -1.0 2.35e+03    -  2.97e-05 7.58e-03f  1
#   64  2.2218832e-03 1.61e+00 1.39e+05  -1.0 5.53e+03    -  2.57e-03 3.96e-03f  1
#   65  2.2233033e-03 1.61e+00 1.47e+05  -1.0 4.86e+03    -  9.77e-03 4.44e-05h  1
#   66  2.2236557e-03 1.61e+00 1.50e+05  -1.0 1.91e+02    -  4.79e-03 7.45e-04h  1
#   67  2.2187881e-03 1.58e+00 1.36e+05  -1.0 3.62e+02    -  5.04e-05 1.44e-02f  1
#   68  2.2128286e-03 1.58e+00 1.36e+05  -1.0 6.73e+03    -  7.37e-04 1.28e-03h  1
#   69  2.2128207e-03 1.58e+00 1.40e+05  -1.0 4.59e+03    -  6.66e-03 2.54e-05h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   70  2.2024427e-03 1.58e+00 1.38e+05  -1.0 1.16e+03    -  2.48e-05 2.63e-03h  1
#   71  2.2967148e-03 1.57e+00 1.35e+05  -1.0 6.35e+03    -  5.00e-05 3.96e-03f  1
#   72  2.2986744e-03 1.57e+00 1.49e+05  -1.0 5.24e+03    -  1.28e-02 4.77e-05h  1
#   73  2.3035785e-03 1.57e+00 1.48e+05  -1.0 6.38e+02    -  1.68e-03 1.90e-03h  1
#   74  2.3250802e-03 1.56e+00 1.33e+05  -1.0 1.21e+03    -  1.89e-05 4.43e-03f  1
#   75  2.3252730e-03 1.56e+00 1.35e+05  -1.0 1.09e+03    -  5.58e-03 4.95e-05h  1
#   76  2.3053815e-03 1.55e+00 1.31e+05  -1.0 4.71e+02    -  5.01e-05 7.24e-03f  1
#   77  2.2684919e-03 1.55e+00 1.31e+05  -1.0 7.78e+03    -  4.29e-04 1.58e-03f  1
#   78  2.2681653e-03 1.55e+00 1.33e+05  -1.0 5.11e+03    -  5.48e-03 3.32e-05h  1
#   79  2.2526934e-03 1.54e+00 1.32e+05  -1.0 1.33e+03    -  2.20e-05 2.34e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   80  2.3261799e-03 1.54e+00 1.30e+05  -1.0 7.35e+03    -  1.14e-04 4.08e-03f  1
#   81  2.3283249e-03 1.54e+00 1.34e+05  -1.0 6.43e+03    -  1.09e-02 4.60e-05h  1
#   82  2.3293526e-03 1.54e+00 1.35e+05  -1.0 2.30e+02    -  3.83e-03 8.36e-04h  1
#   83  2.3415764e-03 1.51e+00 1.27e+05  -1.0 6.38e+02    -  4.13e-05 1.55e-02f  1
#   84  2.3414385e-03 1.51e+00 1.28e+05  -1.0 6.56e+03    -  1.54e-03 4.30e-05h  1
#   85  2.3377352e-03 1.51e+00 1.28e+05  -1.0 2.38e+03    -  1.79e-03 6.37e-04h  1
#   86  2.3287624e-03 1.51e+00 1.27e+05  -1.0 1.53e+03    -  1.59e-05 2.20e-03f  1
#   87  2.3745851e-03 1.50e+00 1.26e+05  -1.0 8.40e+03    -  2.27e-04 2.06e-03f  1
#   88  2.3755260e-03 1.50e+00 1.38e+05  -1.0 6.10e+03    -  9.12e-03 2.95e-05h  1
#   89  2.3786543e-03 1.50e+00 1.61e+05  -1.0 7.48e+02    -  8.42e-03 1.91e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   90  2.4098789e-03 1.48e+00 1.12e+05  -1.0 7.29e+02    -  8.45e-05 1.31e-02f  1
#   91  2.4320071e-03 1.48e+00 1.12e+05  -1.0 7.24e+03    -  5.56e-05 8.59e-04f  1
#   92  2.4322876e-03 1.48e+00 1.19e+05  -1.0 2.16e+03    -  7.36e-03 2.89e-05h  1
#   93  2.4321884e-03 1.47e+00 1.08e+05  -1.0 2.33e+02    -  6.02e-05 8.51e-03f  1
#   94  2.4255319e-03 1.46e+00 1.07e+05  -1.0 4.11e+02   0.0 2.09e-03 6.60e-03h  1
#   95  2.4255240e-03 1.46e+00 1.07e+05  -1.0 1.25e+03  -0.5 1.93e-03 1.50e-05h  1
#   96  2.4075709e-03 1.46e+00 1.07e+05  -1.0 1.15e+04    -  1.30e-04 4.10e-04h  1
#   97  2.4067175e-03 1.46e+00 1.07e+05  -1.0 2.86e+03    -  1.42e-03 5.33e-05h  1
#   98  2.3887025e-03 1.45e+00 1.07e+05  -1.0 1.60e+03    -  1.26e-05 1.62e-03h  1
#   99  2.3999199e-03 1.45e+00 1.07e+05  -1.0 1.19e+04    -  8.75e-05 2.66e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  100  2.4611895e-03 1.45e+00 1.07e+05  -1.0 1.12e+04    -  5.29e-03 8.36e-04h  1
#  101  2.4619598e-03 1.45e+00 1.07e+05  -1.0 3.84e+03    -  4.32e-03 2.44e-05h  1
#  102  2.4587997e-03 1.45e+00 1.06e+05  -1.0 1.49e+03    -  3.44e-05 1.64e-03f  1
#  103  2.4566189e-03 1.45e+00 1.06e+05  -1.0 4.16e+03    -  6.95e-04 1.39e-04h  1
#  104  2.4501639e-03 1.45e+00 1.06e+05  -1.0 1.59e+03    -  7.64e-04 8.23e-04h  1
#  105  2.4357333e-03 1.44e+00 1.06e+05  -1.0 2.48e+03    -  8.30e-06 1.77e-03h  1
#  106  2.5268394e-03 1.44e+00 1.06e+05  -1.0 1.31e+04    -  3.15e-04 2.39e-03f  1
#  107  2.5291896e-03 1.44e+00 1.10e+05  -1.0 1.06e+04    -  7.14e-03 2.92e-05h  1
#  108  2.5327592e-03 1.44e+00 1.51e+05  -1.0 7.20e+02    -  1.26e-02 1.12e-03h  1
#  109  2.5736814e-03 1.42e+00 1.12e+05  -1.0 7.16e+02    -  1.28e-04 1.07e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  110  2.5767066e-03 1.42e+00 1.11e+05  -1.0 3.96e+03    -  1.47e-05 2.57e-04h  1
#  111  2.5775020e-03 1.42e+00 1.15e+05  -1.0 2.19e+03    -  4.71e-03 1.29e-04h  1
#  112  2.5740947e-03 1.42e+00 1.12e+05  -1.0 1.53e+02    -  7.08e-05 3.02e-03f  1
#  113  2.5695410e-03 1.41e+00 1.06e+05  -1.0 1.98e+02    -  4.24e-03 8.50e-03f  1
#  114  2.5026618e-03 1.39e+00 9.77e+04  -1.0 2.13e+03    -  5.23e-05 1.18e-02f  1
#  115  2.5318188e-03 1.39e+00 9.69e+04  -1.0 1.09e+04    -  2.40e-03 1.02e-03h  1
#  116  2.5339293e-03 1.39e+00 9.41e+04  -1.0 9.10e+03    -  4.04e-03 8.86e-05h  1
#  117  2.5570645e-03 1.39e+00 9.38e+04  -1.0 4.94e+03    -  1.55e-03 1.38e-03h  1
#  118  2.5916833e-03 1.38e+00 9.40e+04  -1.0 9.42e+03    -  2.37e-04 6.57e-04h  1
#  119  2.5921491e-03 1.38e+00 9.95e+04  -1.0 1.16e+03    -  6.72e-03 5.38e-05h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  120  2.5918975e-03 1.37e+00 1.00e+05  -1.0 1.06e+03    -  6.62e-05 1.18e-02f  1
#  121  2.6260537e-03 1.37e+00 1.00e+05  -1.0 1.25e+04    -  1.02e-03 1.16e-03h  1
#  122  2.6293620e-03 1.37e+00 9.73e+04  -1.0 1.05e+04    -  3.25e-03 1.15e-04h  1
#  123  2.6525328e-03 1.36e+00 9.67e+04  -1.0 5.78e+03    -  1.64e-03 1.11e-03h  1
#  124  2.6699637e-03 1.36e+00 9.71e+04  -1.0 5.89e+03    -  2.14e-05 5.96e-04h  1
#  125  2.6703206e-03 1.36e+00 1.99e+05  -1.0 1.19e+03    -  3.37e-02 7.49e-05h  1
#  126  2.7203790e-03 1.34e+00 1.44e+05  -1.0 7.60e+02    -  3.34e-04 1.57e-02f  1
#  127  2.7208761e-03 1.34e+00 1.44e+05  -1.0 1.27e+03    -  8.60e-05 9.51e-05h  1
#  128  2.7209837e-03 1.34e+00 1.53e+05  -1.0 1.91e+02    -  7.03e-03 2.10e-04h  1
#  129  2.6790273e-03 1.32e+00 1.29e+05  -1.0 1.01e+03    -  7.89e-05 1.67e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  130  2.6761481e-03 1.32e+00 1.27e+05  -1.0 1.32e+04    -  1.30e-03 8.48e-05h  1
#  131  2.6659555e-03 1.32e+00 1.26e+05  -1.0 9.94e+03    -  2.27e-03 8.03e-04h  1
#  132  2.6577179e-03 1.32e+00 1.25e+05  -1.0 7.75e+02    -  5.40e-04 1.12e-03h  1
#  133  2.7353572e-03 1.31e+00 1.28e+05  -1.0 1.16e+04    -  2.46e-05 2.03e-03f  1
#  134  2.7369794e-03 1.31e+00 1.24e+05  -1.0 9.04e+03    -  5.35e-03 2.59e-05h  1
#  135  2.7414186e-03 1.31e+00 1.26e+05  -1.0 1.88e+02    -  4.31e-03 2.37e-03h  1
#  136  2.7284794e-03 1.31e+00 1.23e+05  -1.0 2.89e+03    -  5.21e-05 4.11e-03f  1
#  137  2.7257304e-03 1.30e+00 1.21e+05  -1.0 1.47e+04    -  8.55e-04 1.53e-04h  1
#  138  2.7276040e-03 1.30e+00 1.19e+05  -1.0 1.04e+04    -  2.68e-03 6.27e-04h  1
#  139  2.7186203e-03 1.30e+00 1.17e+05  -1.0 9.19e+02    -  1.18e-05 1.45e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  140  2.8604328e-03 1.30e+00 1.21e+05  -1.0 1.72e+04    -  3.56e-05 1.55e-03f  1
#  141  2.8628655e-03 1.30e+00 1.21e+05  -1.0 9.11e+03    -  1.03e-02 3.01e-05h  1
#  142  2.8712268e-03 1.30e+00 2.00e+05  -1.0 5.87e+02    -  2.93e-02 2.51e-03h  1
#  143  2.8525534e-03 1.27e+00 1.48e+05  -1.0 4.53e+02    -  1.65e-04 1.90e-02f  1
#  144  2.8441388e-03 1.27e+00 1.89e+05  -1.0 8.18e+02    -  1.87e-02 5.34e-03h  1
#  145  2.8293644e-03 1.26e+00 1.73e+05  -1.0 6.28e+02    -  4.04e-05 5.56e-03h  1
#  146  2.8794334e-03 1.22e+00 1.01e+05  -1.0 8.25e+02    -  7.89e-03 3.00e-02f  1
#  147  2.8897182e-03 1.22e+00 9.68e+04  -1.0 1.17e+03    -  7.49e-05 2.49e-03h  1
#  148  2.8980300e-03 1.22e+00 9.68e+04  -1.0 4.20e+04    -  2.28e-05 6.47e-05f  2
#  149  2.8996920e-03 1.22e+00 9.68e+04  -1.0 3.93e+04    -  8.69e-04 1.15e-05f  4
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  150  2.9132210e-03 1.22e+00 9.73e+04  -1.0 1.38e+04    -  1.82e-03 2.30e-04h  1
#  151  2.9139857e-03 1.22e+00 9.90e+04  -1.0 3.65e+02    -  4.67e-03 8.50e-04h  1
#  152  2.9295134e-03 1.20e+00 9.71e+04  -1.0 2.63e+02    -  9.67e-05 1.46e-02f  1
#  153  2.9457313e-03 1.18e+00 1.10e+05  -1.0 4.27e+02    -  1.01e-03 1.53e-02f  1
#  154  2.9128927e-03 1.16e+00 1.21e+05  -1.0 1.15e+03  -1.0 5.40e-03 1.54e-02f  1
#  155  2.9060317e-03 1.16e+00 1.22e+05  -1.0 4.59e+03  -1.4 1.73e-04 9.54e-04h  1
#  156r 2.9060317e-03 1.16e+00 1.00e+03   0.1 0.00e+00  -1.9 0.00e+00 3.56e-07R  6
#  157r 2.8854686e-03 5.56e-01 1.11e+03   0.1 1.66e+03    -  5.66e-02 2.64e-02f  1
#  158  2.8833854e-03 5.56e-01 4.63e+01  -1.0 2.95e+03    -  9.62e-03 5.39e-04h  1
#  159  2.9654819e-03 5.54e-01 4.38e+01  -1.0 4.82e+03    -  3.60e-03 3.98e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  160  2.9682410e-03 5.52e-01 6.41e+01  -1.0 5.66e+03    -  7.72e-03 4.05e-03f  1
#  161  2.9693053e-03 5.51e-01 1.51e+02  -1.0 3.53e+03    -  7.24e-04 1.18e-04h  1
#  162  3.0163164e-03 5.50e-01 5.89e+01  -1.0 7.30e+03    -  8.82e-05 3.52e-03f  1
#  163  3.0131116e-03 5.49e-01 7.26e+01  -1.0 3.21e+03    -  5.02e-04 2.56e-04h  1
#  164  3.0094341e-03 5.47e-01 3.89e+01  -1.0 8.56e+03    -  1.17e-03 3.61e-03f  1
#  165  3.1047313e-03 5.46e-01 6.54e+01  -1.0 8.01e+03    -  3.80e-03 2.14e-03h  1
#  166  3.1024319e-03 5.46e-01 6.05e+01  -1.0 4.54e+03    -  3.35e-04 4.11e-04h  1
#  167  3.1033508e-03 5.45e-01 7.07e+01  -1.0 8.76e+03    -  2.18e-03 1.62e-03h  1
#  168  3.1712643e-03 5.44e-01 1.49e+02  -1.0 8.35e+03    -  6.53e-03 2.22e-03h  1
#  169  3.1728763e-03 5.44e-01 7.19e+02  -1.0 2.26e+03    -  1.44e-03 1.11e-04h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  170  3.2177949e-03 5.43e-01 2.33e+02  -1.0 7.74e+03    -  3.03e-05 1.83e-03h  1
#  171  3.2024694e-03 5.43e-01 2.12e+02  -1.0 7.49e+03    -  3.58e-04 4.54e-04h  1
#  172  3.2162124e-03 5.42e-01 9.62e+01  -1.0 1.51e+04    -  5.44e-04 2.07e-03h  1
#  173  3.2510367e-03 5.41e-01 1.65e+02  -1.0 1.39e+04    -  1.17e-03 5.12e-04h  1
#  174  3.2889058e-03 5.41e-01 1.24e+02  -1.0 1.12e+04    -  2.46e-04 5.57e-04h  1
#  175  3.2835255e-03 5.41e-01 1.24e+02  -1.0 6.38e+03    -  3.44e-04 3.44e-04h  1
#  176  3.3138127e-03 5.40e-01 3.57e+01  -1.0 1.57e+04    -  4.16e-04 1.51e-03f  1
#  177  3.3514747e-03 5.40e-01 5.52e+01  -1.0 1.41e+04    -  6.81e-04 5.20e-04h  1
#  178  3.4658272e-03 5.39e-01 4.56e+01  -1.0 1.40e+04    -  2.44e-04 1.06e-03h  1
#  179  3.4665797e-03 5.39e-01 8.43e+02  -1.0 1.12e+03    -  1.82e-03 6.46e-05h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  180  3.4657426e-03 5.37e-01 7.94e+03  -1.0 2.86e+02    -  1.58e-02 3.92e-03h  1
#  181  3.4418046e-03 5.27e-01 2.83e+03  -1.0 1.06e+03    -  2.21e-04 1.83e-02h  1
#  182  3.4534059e-03 5.26e-01 2.26e+03  -1.0 3.33e+03    -  3.09e-03 2.11e-03h  1
#  183  3.5586526e-03 5.23e-01 7.57e+02  -1.0 3.58e+03    -  8.54e-03 5.96e-03h  1
#  184  3.5596967e-03 5.22e-01 1.92e+03  -1.0 1.95e+02    -  6.02e-03 1.51e-03h  1
#  185  3.5671149e-03 5.17e-01 2.39e+03  -1.0 2.24e+03    -  1.58e-03 8.94e-03h  1
#  186  3.7375046e-03 5.09e-01 1.03e+04  -1.0 1.80e+03    -  2.73e-03 1.61e-02h  1
#  187  3.7399296e-03 5.09e-01 3.20e+03  -1.0 2.91e+02    -  1.25e-02 9.86e-04h  1
#  188  3.7562562e-03 5.01e-01 9.31e+03  -1.0 1.12e+03    -  5.12e-03 1.54e-02h  1
#  189  3.8835477e-03 4.89e-01 2.72e+03  -1.0 1.01e+03    -  3.39e-02 2.34e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  190  3.8867995e-03 4.87e-01 2.33e+04  -1.0 2.53e+02    -  4.55e-02 3.28e-03h  1
#  191  3.9245223e-03 4.68e-01 1.13e+05  -1.0 2.13e+02    -  1.91e-01 3.91e-02f  1
#  192  3.9222352e-03 4.64e-01 1.12e+05  -1.0 9.30e+01    -  7.70e-03 8.06e-03h  1
#  193  3.9616336e-03 3.61e-01 3.76e+04  -1.0 2.21e+02    -  1.27e-01 2.22e-01f  1
#  194  3.9643563e-03 3.60e-01 9.13e+04  -1.0 1.51e+02    -  8.81e-02 3.21e-03h  1
#  195  4.0235153e-03 2.66e-01 2.85e+04  -1.0 1.91e+02    -  1.94e-01 2.61e-01h  1
#  196  4.0265108e-03 2.65e-01 6.26e+04  -1.0 1.21e+02    -  5.56e-02 4.08e-03h  1
#  197  4.0184091e-03 2.52e-01 3.73e+04  -1.0 7.32e+01    -  1.07e-02 4.66e-02f  1
#  198  4.1131890e-03 1.78e-01 4.20e+05  -1.0 1.57e+02    -  8.51e-01 2.94e-01h  1
#  199  4.1182663e-03 1.77e-01 4.59e+05  -1.0 9.07e+01    -  1.39e-01 8.21e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  200  4.2428635e-03 1.01e-01 1.52e+05  -1.0 1.16e+02    -  3.67e-02 4.26e-01h  1
#  201  4.2469584e-03 1.00e-01 2.60e+05  -1.0 1.36e+02    -  1.72e-01 5.39e-03h  1
#  202  4.2893365e-03 7.16e-02 1.21e+05  -1.0 1.44e+02    -  1.93e-03 2.84e-01h  1
#  203  4.2726394e-03 6.81e-02 1.18e+05  -1.0 2.30e+01   0.3 1.86e-02 4.82e-02h  1
#  204  4.2531675e-03 6.80e-02 1.17e+05  -1.0 5.52e+02  -0.2 1.92e-03 1.61e-03f  1
#  205  4.1261707e-03 5.73e-02 1.56e+05  -1.0 3.63e+01   0.3 5.08e-02 1.54e-01f  1
#  206  4.0896324e-03 4.98e-02 1.92e+05  -1.0 1.37e+01   0.7 4.81e-01 1.28e-01f  1
#  207  3.9052902e-03 3.88e-02 1.32e+05  -1.0 6.98e+01   0.2 1.56e-01 2.18e-01f  1
#  208  3.9043850e-03 3.85e-02 6.13e+05  -1.0 2.32e+01   0.6 1.00e+00 6.42e-03h  1
#  209  3.8994353e-03 3.80e-02 6.49e+05  -1.0 3.44e+01   0.2 4.15e-01 1.33e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  210  3.7273057e-03 1.16e-02 5.55e+04  -1.0 9.18e+00   0.6 1.00e+00 9.17e-01f  1
#  211  3.7210292e-03 1.16e-02 4.45e+05  -1.0 4.69e+00   1.0 7.37e-01 1.12e-01h  1
#  212  3.7197802e-03 1.16e-02 4.44e+05  -1.0 2.26e+01   0.5 2.99e-03 2.99e-03s 14
#  213  3.6523729e-03 1.16e-02 6.92e+05  -1.0 5.43e+00   1.0 1.00e+00 0.00e+00S 14
#  214  3.6268464e-03 1.23e-02 5.02e+05  -1.0 4.99e+01   0.5 1.00e+00 5.10e-01H  1
#  215  3.6047870e-03 1.22e-02 2.33e+05  -1.0 6.16e+00   0.9 1.26e-02 3.77e-01f  2
#  216  3.5874195e-03 1.22e-02 8.67e+04  -1.0 2.29e+00   1.3 6.28e-01 6.28e-01s 22
#  217  3.5643859e-03 1.21e-02 7.83e+04  -1.0 1.51e+01   0.9 9.69e-02 9.69e-02s 22
#  218  3.5281005e-03 1.21e-02 7.99e+02  -1.0 3.23e+00   1.3 1.00e+00 1.00e+00s 22
#  219r 3.5281005e-03 1.21e-02 1.00e+03  -1.7 0.00e+00   0.8 0.00e+00 4.49e-07R 20
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  220r 3.5350314e-03 1.46e-02 9.74e+02  -1.7 1.18e+03    -  8.83e-02 2.52e-02f  1
#  221r 3.5974130e-03 1.94e-02 9.23e+02  -1.7 1.04e+03    -  1.83e-02 5.31e-02f  1
#  222r 3.6224484e-03 2.07e-02 9.03e+02  -1.7 7.54e+02    -  2.08e-01 2.12e-02f  1
#  223r 3.6789082e-03 2.47e-02 8.24e+02  -1.7 5.41e+02    -  7.99e-02 8.77e-02f  1
#  224r 3.7383457e-03 2.84e-02 7.37e+02  -1.7 4.06e+02    -  1.51e-01 1.05e-01f  1
#  225r 3.7414577e-03 2.92e-02 7.13e+02  -1.7 2.56e+02    -  4.48e-02 3.25e-02f  1
#  226r 3.7633267e-03 3.09e-02 6.58e+02  -1.7 2.42e+02    -  1.12e-01 7.65e-02f  1
#  227r 3.7823502e-03 3.44e-02 5.49e+02  -1.7 2.18e+02    -  3.31e-01 1.66e-01f  1
#  228r 3.6905571e-03 4.02e-02 3.77e+02  -1.7 2.04e+02    -  2.50e-01 3.26e-01f  1
#  229r 3.5007783e-03 4.67e-02 1.82e+02  -1.7 1.42e+02    -  5.12e-01 5.37e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  230r 3.1098259e-03 5.03e-02 1.06e+02  -1.7 5.54e+01    -  5.64e-01 8.80e-01f  1
#  231r 2.8919432e-03 4.69e-02 3.54e-02  -1.7 4.40e+01    -  1.00e+00 1.00e+00f  1
#  232r 3.0291855e-03 4.81e-02 2.44e+01  -3.8 3.03e+01    -  9.57e-01 5.17e-01f  1
#  233r 3.0985345e-03 4.91e-02 4.15e+01  -3.8 9.44e+01  -4.0 6.42e-01 2.37e-01f  1
#  234r 3.1198067e-03 5.18e-02 3.68e+01  -3.8 3.65e+02  -4.5 1.29e-01 1.26e-01f  1
#  235r 3.0198731e-03 5.33e-02 2.69e+01  -3.8 1.62e+02  -4.1 1.78e-01 2.00e-01f  1
#  236r 3.1225857e-03 5.63e-02 7.03e+01  -3.8 1.39e+02  -4.5 8.51e-01 3.76e-01f  1
#  237r 3.1523071e-03 5.45e-02 5.79e+01  -3.8 2.31e+02  -5.0 1.43e-04 1.03e-01f  1
#  238r 3.2770747e-03 6.41e-02 6.58e+01  -3.8 9.07e+03  -5.5 1.52e-03 1.07e-02f  1
#  239r 3.2756320e-03 6.41e-02 6.89e+01  -3.8 2.35e+02  -4.2 8.14e-02 7.94e-04f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  240r 3.2932972e-03 6.48e-02 5.17e+01  -3.8 6.98e+01  -4.6 4.03e-01 1.39e-01f  1
#  241r 3.1652909e-03 7.00e-02 6.32e+01  -3.8 4.01e+02  -5.1 2.36e-02 1.40e-01f  1
#  242r 3.1440607e-03 7.54e-02 4.22e+01  -3.8 9.34e+01  -4.7 3.20e-01 6.09e-01f  1
#  243r 3.1458021e-03 7.63e-02 1.56e+01  -3.8 4.73e+02  -5.2 2.38e-01 2.14e-02f  1
#  244r 3.1458570e-03 7.68e-02 6.87e+01  -3.8 8.51e+02  -5.6 3.50e-01 5.88e-03f  1
#  245r 3.1458762e-03 7.68e-02 8.82e+01  -3.8 9.84e+02  -5.2 1.58e-01 9.26e-05h  1
#  246r 3.1460227e-03 7.63e-02 8.81e+01  -3.8 3.13e+03    -  1.43e-05 1.73e-03h  6
#  247r 3.1459203e-03 7.65e-02 8.32e+01  -3.8 1.92e+04  -5.7 3.21e-03 1.03e-04f  1
#  248r 3.1419000e-03 8.44e-02 1.02e+02  -3.8 8.60e+03    -  1.78e-06 1.61e-02f  1
#  249r 3.1436871e-03 8.47e-02 2.39e+01  -3.8 6.12e+01  -4.4 1.00e+00 5.62e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  250r 3.1568417e-03 8.78e-02 8.78e+01  -3.8 1.95e+02  -4.8 8.08e-01 1.91e-01f  1
#  251r 3.1040691e-03 9.02e-02 8.30e+01  -3.8 2.91e+02  -5.3 3.35e-01 9.49e-02f  1
#  252r 3.1342304e-03 9.01e-02 2.94e+01  -3.8 1.73e+01    -  8.54e-01 1.66e-01f  1
#  253r 3.1744928e-03 9.01e-02 6.75e+00  -3.8 4.88e+00    -  1.00e+00 7.95e-01f  1
#  254r 3.1790780e-03 9.01e-02 1.83e-04  -3.8 3.19e-01    -  1.00e+00 1.00e+00f  1
#  255r 3.2106758e-03 9.01e-02 3.06e-01  -5.7 4.00e-01    -  1.00e+00 9.73e-01f  1
#  256r 3.2726435e-03 9.01e-02 2.01e+02  -5.7 6.56e+01    -  3.28e-01 3.13e-02f  1
#  257r 3.3966669e-03 9.01e-02 5.50e+02  -5.7 4.19e+01    -  1.00e+00 8.40e-02f  1
#  258r 3.5816737e-03 9.01e-02 4.34e+02  -5.7 1.91e+01    -  1.00e+00 1.86e-01f  1
#  259r 3.9211643e-03 9.00e-02 2.10e+02  -5.7 6.60e+00    -  1.00e+00 5.21e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  260r 4.0305762e-03 9.00e-02 1.13e+02  -5.7 2.83e+00    -  1.00e+00 4.62e-01f  1
#  261r 4.0348577e-03 9.00e-02 9.67e+01  -5.7 7.89e-01    -  1.00e+00 1.42e-01f  1
#  262r 4.0441444e-03 9.00e-02 5.10e-02  -5.7 8.78e-01    -  9.00e-01 1.00e+00f  1
#
# Number of Iterations....: 262
#
#                                    (scaled)                 (unscaled)
# Objective...............:   4.0442785572955414e-03    4.0442785572955414e-03
# Dual infeasibility......:   1.6000008293588053e-02    1.6000008293588053e-02
# Constraint violation....:   9.0037283302071558e-02    9.0037283302071558e-02
# Variable bound violation:   4.1588133249670367e-09    4.1588133249670367e-09
# Complementarity.........:   1.9329976568898910e-06    1.9329976568898910e-06
# Overall NLP error.......:   9.0037283302071558e-02    9.0037283302071558e-02
#
#
# Number of objective function evaluations             = 345
# Number of objective gradient evaluations             = 221
# Number of equality constraint evaluations            = 345
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 266
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 263
# Total seconds in IPOPT                               = 1.983
#
# EXIT: Converged to a point of local infeasibility. Problem may be infeasible.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver: Ipopt 3.14.13\x3a Converged to a locally infeasible
#       point. Problem may be infeasible.

# %%
# For debugging:
print(results.solver.status) # tells you if the solver had any errors/ warnings
print(results.solver.termination_condition) # tells you if the solution was (locally) optimal, feasible, or neither.

# If you want a full print-out of everything going on with your model, use:
#m.pprint() 

# This is your best friend when it comes to figuring out why something's not converging, why the solution looks weird, etc.
# It's probably most handy if you print it to a file:
#instance.pprint(filename='blah.txt')

# You can also pretty print individual elements of the model. e.g.
m.dq.pprint()

# export trajectories
def write_trajectory_to_csv(m, filename, decimal_places=6):
    with open(filename, 'w', newline='') as file:
        writer = csv.writer(file)
        
        # Write header
        writer.writerow(['Time', 'Arm Angle', 'Pendulum Angle', 'Arm Velocity', 'Pendulum Velocity' , 'Arm Acc', 'Pendulum Acc' , 'Torque'])
        
        for n in m.N:
            torque, voltage = calculate_torque_voltage(n, m)
            row = [
                round(m.h.value * (n-1), decimal_places),  # Time
                round(m.q[n, 1].value, decimal_places),   # Arm angle (theta)
                round(m.q[n, 2].value, decimal_places),   # Pendulum angle (alpha)
                round(m.dq[n, 1].value, decimal_places),  # Arm angular velocity
                round(m.dq[n, 2].value, decimal_places),  # Pendulum angular velocity
                round(m.ddq[n, 1].value, decimal_places),  # Arm angular acc
                round(m.ddq[n, 2].value, decimal_places),  # Pendulum angular acc
                round(m.Tc[n].value, decimal_places)       # torque
            ]
            writer.writerow(row)


# # Usage:
write_trajectory_to_csv(m, 'trajectory.csv', decimal_places=4)
# Out:
# warning
# infeasible
# dq : Size=200, Index=N*L
#     Key      : Lower : Value                   : Upper : Fixed : Stale : Domain
#       (1, 1) :  None :  1.5721867782935005e-12 :  None : False : False :  Reals
#       (1, 2) :  None :  -7.621005309455001e-12 :  None : False : False :  Reals
#       (2, 1) :  None :  3.1384923595262296e-12 :  None : False : False :  Reals
#       (2, 2) :  None :  -8.083303776159414e-12 :  None : False : False :  Reals
#       (3, 1) :  None :  4.6983022635737176e-12 :  None : False : False :  Reals
#       (3, 2) :  None : -5.6683470444344846e-12 :  None : False : False :  Reals
#       (4, 1) :  None :      0.5238508826837638 :  None : False : False :  Reals
#       (4, 2) :  None :     -0.5177595748538196 :  None : False : False :  Reals
#       (5, 1) :  None :      1.0477129625191348 :  None : False : False :  Reals
#       (5, 2) :  None :     -1.0355304042383737 :  None : False : False :  Reals
#       (6, 1) :  None :      1.5611882417120135 :  None : False : False :  Reals
#       (6, 2) :  None :     -1.5195549082329294 :  None : False : False :  Reals
#       (7, 1) :  None :      2.0530885228769082 :  None : False : False :  Reals
#       (7, 2) :  None :     -1.9357750086724814 :  None : False : False :  Reals
#       (8, 1) :  None :      2.5118975345621473 :  None : False : False :  Reals
#       (8, 2) :  None :     -2.2521546347796564 :  None : False : False :  Reals
#       (9, 1) :  None :       8.681945911933644 :  None : False : False :  Reals
#       (9, 2) :  None :      -21.62757691860863 :  None : False : False :  Reals
#      (10, 1) :  None :       8.206818527364968 :  None : False : False :  Reals
#      (10, 2) :  None :     -20.994681855587007 :  None : False : False :  Reals
#      (11, 1) :  None :       5.867962228363649 :  None : False : False :  Reals
#      (11, 2) :  None :     -18.274454782280277 :  None : False : False :  Reals
#      (12, 1) :  None :      3.9575942371876627 :  None : False : False :  Reals
#      (12, 2) :  None :     -15.569052106467394 :  None : False : False :  Reals
#      (13, 1) :  None :      2.8671157480189686 :  None : False : False :  Reals
#      (13, 2) :  None :     -13.161861888603704 :  None : False : False :  Reals
#      (14, 1) :  None :      1.8033736466586194 :  None : False : False :  Reals
#      (14, 2) :  None :     -10.988899446524705 :  None : False : False :  Reals
#      (15, 1) :  None :      1.1531943857518145 :  None : False : False :  Reals
#      (15, 2) :  None :      -9.073632190010983 :  None : False : False :  Reals
#      (16, 1) :  None :      0.7614889834703622 :  None : False : False :  Reals
#      (16, 2) :  None :       -7.37896443567203 :  None : False : False :  Reals
#      (17, 1) :  None :      0.5224498038435627 :  None : False : False :  Reals
#      (17, 2) :  None :       -5.89812641979828 :  None : False : False :  Reals
#      (18, 1) :  None :      0.3571253806333924 :  None : False : False :  Reals
#      (18, 2) :  None :      -4.636011368166362 :  None : False : False :  Reals
#      (19, 1) :  None :     0.20947551685027685 :  None : False : False :  Reals
#      (19, 2) :  None :     -3.5934257611804172 :  None : False : False :  Reals
#      (20, 1) :  None :     0.04590624650870567 :  None : False : False :  Reals
#      (20, 2) :  None :       -2.75851338694999 :  None : False : False :  Reals
#      (21, 1) :  None :    -0.14871590591387773 :  None : False : False :  Reals
#      (21, 2) :  None :      -2.107491436345428 :  None : False : False :  Reals
#      (22, 1) :  None :    -0.37759714261963795 :  None : False : False :  Reals
#      (22, 2) :  None :     -1.6105794706969483 :  None : False : False :  Reals
#      (23, 1) :  None :      -0.637945895547744 :  None : False : False :  Reals
#      (23, 2) :  None :     -1.2378876916433157 :  None : False : False :  Reals
#      (24, 1) :  None :      -0.924834815697699 :  None : False : False :  Reals
#      (24, 2) :  None :     -0.9629470957293111 :  None : False : False :  Reals
#      (25, 1) :  None :      -1.233192249021426 :  None : False : False :  Reals
#      (25, 2) :  None :      -0.764027385529563 :  None : False : False :  Reals
#      (26, 1) :  None :     -1.5586258054251887 :  None : False : False :  Reals
#      (26, 2) :  None :     -0.6241449241597388 :  None : False : False :  Reals
#      (27, 1) :  None :      -1.897656140694146 :  None : False : False :  Reals
#      (27, 2) :  None :     -0.5305114016372547 :  None : False : False :  Reals
#      (28, 1) :  None :      -2.247701373773304 :  None : False : False :  Reals
#      (28, 2) :  None :     -0.4738521237162501 :  None : False : False :  Reals
#      (29, 1) :  None :      -2.606981056757933 :  None : False : False :  Reals
#      (29, 2) :  None :     -0.4477901733508274 :  None : False : False :  Reals
#      (30, 1) :  None :     -2.9744132340129577 :  None : False : False :  Reals
#      (30, 2) :  None :    -0.44836698437762296 :  None : False : False :  Reals
#      (31, 1) :  None :     -3.3495041676373956 :  None : False : False :  Reals
#      (31, 2) :  None :     -0.4736865356781569 :  None : False : False :  Reals
#      (32, 1) :  None :     -3.6811859061284116 :  None : False : False :  Reals
#      (32, 2) :  None :      -0.473666312023241 :  None : False : False :  Reals
#      (33, 1) :  None :      -3.999178482127248 :  None : False : False :  Reals
#      (33, 2) :  None :    -0.47931326866479995 :  None : False : False :  Reals
#      (34, 1) :  None :     -4.3186136154333665 :  None : False : False :  Reals
#      (34, 2) :  None :     -0.5059145746156252 :  None : False : False :  Reals
#      (35, 1) :  None :      -4.662023579599562 :  None : False : False :  Reals
#      (35, 2) :  None :     -0.5762590239558693 :  None : False : False :  Reals
#      (36, 1) :  None :      -5.031991905052993 :  None : False : False :  Reals
#      (36, 2) :  None :     -0.6944771539247514 :  None : False : False :  Reals
#      (37, 1) :  None :      -5.419171600961096 :  None : False : False :  Reals
#      (37, 2) :  None :     -0.8554679636082603 :  None : False : False :  Reals
#      (38, 1) :  None :      -5.804475744753138 :  None : False : False :  Reals
#      (38, 2) :  None :     -1.0476451581456014 :  None : False : False :  Reals
#      (39, 1) :  None :      -6.160063135687658 :  None : False : False :  Reals
#      (39, 2) :  None :     -1.2539639025180234 :  None : False : False :  Reals
#      (40, 1) :  None :     -6.4514511536485655 :  None : False : False :  Reals
#      (40, 2) :  None :      -1.453500832542453 :  None : False : False :  Reals
#      (41, 1) :  None :      -6.551045296574919 :  None : False : False :  Reals
#      (41, 2) :  None :      -1.534752993466553 :  None : False : False :  Reals
#      (42, 1) :  None :     -6.0536276663594615 :  None : False : False :  Reals
#      (42, 2) :  None :      -1.110977648749931 :  None : False : False :  Reals
#      (43, 1) :  None :      -5.591562439281323 :  None : False : False :  Reals
#      (43, 2) :  None :     -0.8072900569087741 :  None : False : False :  Reals
#      (44, 1) :  None :      -5.155058678425649 :  None : False : False :  Reals
#      (44, 2) :  None :     -0.5860297947665907 :  None : False : False :  Reals
#      (45, 1) :  None :      -4.736607274885075 :  None : False : False :  Reals
#      (45, 2) :  None :    -0.42083859715987026 :  None : False : False :  Reals
#      (46, 1) :  None :      -4.333160226281136 :  None : False : False :  Reals
#      (46, 2) :  None :     -0.2956580516734318 :  None : False : False :  Reals
#      (47, 1) :  None :      -3.952504688346931 :  None : False : False :  Reals
#      (47, 2) :  None :     -0.2089653543931019 :  None : False : False :  Reals
#      (48, 1) :  None :     -3.5885146536134456 :  None : False : False :  Reals
#      (48, 2) :  None :    -0.14836404568591743 :  None : False : False :  Reals
#      (49, 1) :  None :     -3.2355025927732974 :  None : False : False :  Reals
#      (49, 2) :  None :     -0.1041378826134912 :  None : False : False :  Reals
#      (50, 1) :  None :     -2.8898539921015987 :  None : False : False :  Reals
#      (50, 2) :  None :    -0.07004924232541852 :  None : False : False :  Reals
#      (51, 1) :  None :     -2.5492651741280814 :  None : False : False :  Reals
#      (51, 2) :  None :     -0.0420356408049285 :  None : False : False :  Reals
#      (52, 1) :  None :     -2.2122216409659594 :  None : False : False :  Reals
#      (52, 2) :  None :    -0.01735484169279105 :  None : False : False :  Reals
#      (53, 1) :  None :     -1.8778082606866577 :  None : False : False :  Reals
#      (53, 2) :  None :    0.005819105053528355 :  None : False : False :  Reals
#      (54, 1) :  None :      -1.545534157443452 :  None : False : False :  Reals
#      (54, 2) :  None :    0.028710722181926118 :  None : False : False :  Reals
#      (55, 1) :  None :     -1.2152920504366116 :  None : False : False :  Reals
#      (55, 2) :  None :     0.05207777767945067 :  None : False : False :  Reals
#      (56, 1) :  None :     -0.8870987596676992 :  None : False : False :  Reals
#      (56, 2) :  None :     0.07652983993362478 :  None : False : False :  Reals
#      (57, 1) :  None :     -0.5625978153067489 :  None : False : False :  Reals
#      (57, 2) :  None :     0.10109863741785881 :  None : False : False :  Reals
#      (58, 1) :  None :     -0.2410516267957805 :  None : False : False :  Reals
#      (58, 2) :  None :     0.12719930160217152 :  None : False : False :  Reals
#      (59, 1) :  None :     0.07292031733672197 :  None : False : False :  Reals
#      (59, 2) :  None :       0.151017148463322 :  None : False : False :  Reals
#      (60, 1) :  None :     0.37717129710139374 :  None : False : False :  Reals
#      (60, 2) :  None :       0.171253658146111 :  None : False : False :  Reals
#      (61, 1) :  None :      0.6725036178451107 :  None : False : False :  Reals
#      (61, 2) :  None :     0.18944525179398897 :  None : False : False :  Reals
#      (62, 1) :  None :      0.9598847901263596 :  None : False : False :  Reals
#      (62, 2) :  None :     0.20718144430545293 :  None : False : False :  Reals
#      (63, 1) :  None :      1.2401489874099805 :  None : False : False :  Reals
#      (63, 2) :  None :       0.225881138584603 :  None : False : False :  Reals
#      (64, 1) :  None :      1.5138639605407205 :  None : False : False :  Reals
#      (64, 2) :  None :     0.24673335862096726 :  None : False : False :  Reals
#      (65, 1) :  None :       1.781355464205177 :  None : False : False :  Reals
#      (65, 2) :  None :      0.2707866671481831 :  None : False : False :  Reals
#      (66, 1) :  None :      2.0424499264404523 :  None : False : False :  Reals
#      (66, 2) :  None :       0.298753208515014 :  None : False : False :  Reals
#      (67, 1) :  None :      2.2962773112055053 :  None : False : False :  Reals
#      (67, 2) :  None :     0.33086883609190365 :  None : False : False :  Reals
#      (68, 1) :  None :       2.540999890930815 :  None : False : False :  Reals
#      (68, 2) :  None :      0.3666679305618213 :  None : False : False :  Reals
#      (69, 1) :  None :      2.7743118361321506 :  None : False : False :  Reals
#      (69, 2) :  None :      0.4054975474790221 :  None : False : False :  Reals
#      (70, 1) :  None :      2.9939530110786254 :  None : False : False :  Reals
#      (70, 2) :  None :     0.44700928184389177 :  None : False : False :  Reals
#      (71, 1) :  None :        3.19674984440246 :  None : False : False :  Reals
#      (71, 2) :  None :     0.49018305135986195 :  None : False : False :  Reals
#      (72, 1) :  None :      3.3760866060985384 :  None : False : False :  Reals
#      (72, 2) :  None :      0.5308132196067221 :  None : False : False :  Reals
#      (73, 1) :  None :       3.522492403016625 :  None : False : False :  Reals
#      (73, 2) :  None :      0.5620342805208794 :  None : False : False :  Reals
#      (74, 1) :  None :      3.6271640164891057 :  None : False : False :  Reals
#      (74, 2) :  None :      0.5775647868221386 :  None : False : False :  Reals
#      (75, 1) :  None :       3.685971865532391 :  None : False : False :  Reals
#      (75, 2) :  None :      0.5752607395828517 :  None : False : False :  Reals
#      (76, 1) :  None :       3.703090322785358 :  None : False : False :  Reals
#      (76, 2) :  None :      0.5603115479572196 :  None : False : False :  Reals
#      (77, 1) :  None :       3.685558856412418 :  None : False : False :  Reals
#      (77, 2) :  None :      0.5397058154700305 :  None : False : False :  Reals
#      (78, 1) :  None :      3.6273366575884114 :  None : False : False :  Reals
#      (78, 2) :  None :      0.5067364728763609 :  None : False : False :  Reals
#      (79, 1) :  None :      3.5335512382643564 :  None : False : False :  Reals
#      (79, 2) :  None :      0.4653232788673981 :  None : False : False :  Reals
#      (80, 1) :  None :      3.4104781087938805 :  None : False : False :  Reals
#      (80, 2) :  None :      0.4198017145009606 :  None : False : False :  Reals
#      (81, 1) :  None :       3.263529390258058 :  None : False : False :  Reals
#      (81, 2) :  None :      0.3731844100077955 :  None : False : False :  Reals
#      (82, 1) :  None :      3.0972385237826363 :  None : False : False :  Reals
#      (82, 2) :  None :      0.3274086382551746 :  None : False : False :  Reals
#      (83, 1) :  None :      2.9151629577306624 :  None : False : False :  Reals
#      (83, 2) :  None :     0.28342406415142074 :  None : False : False :  Reals
#      (84, 1) :  None :       2.719909687874259 :  None : False : False :  Reals
#      (84, 2) :  None :     0.24133447164416835 :  None : False : False :  Reals
#      (85, 1) :  None :       2.513249577619316 :  None : False : False :  Reals
#      (85, 2) :  None :      0.2005670750131945 :  None : False : False :  Reals
#      (86, 1) :  None :       2.296255219522911 :  None : False : False :  Reals
#      (86, 2) :  None :       0.160016339277076 :  None : False : False :  Reals
#      (87, 1) :  None :      2.0694191746502333 :  None : False : False :  Reals
#      (87, 2) :  None :     0.11813195923795343 :  None : False : False :  Reals
#      (88, 1) :  None :      1.8327406052781208 :  None : False : False :  Reals
#      (88, 2) :  None :     0.07294902570330337 :  None : False : False :  Reals
#      (89, 1) :  None :      1.5857999707210082 :  None : False : False :  Reals
#      (89, 2) :  None :     0.02208580160169575 :  None : False : False :  Reals
#      (90, 1) :  None :      1.3278807210547658 :  None : False : False :  Reals
#      (90, 2) :  None :    -0.03723038713794528 :  None : False : False :  Reals
#      (91, 1) :  None :      1.0581915563190787 :  None : False : False :  Reals
#      (91, 2) :  None :    -0.10805607487191085 :  None : False : False :  Reals
#      (92, 1) :  None :      0.7760593888540542 :  None : False : False :  Reals
#      (92, 2) :  None :    -0.19367048277438095 :  None : False : False :  Reals
#      (93, 1) :  None :      0.4820245999204199 :  None : False : False :  Reals
#      (93, 2) :  None :     -0.2966396519009295 :  None : False : False :  Reals
#      (94, 1) :  None :      0.1797359744321975 :  None : False : False :  Reals
#      (94, 2) :  None :    -0.41710446258737427 :  None : False : False :  Reals
#      (95, 1) :  None :    -0.12048513401816584 :  None : False : False :  Reals
#      (95, 2) :  None :     -0.5493957926408117 :  None : False : False :  Reals
#      (96, 1) :  None :     -0.3953377682349606 :  None : False : False :  Reals
#      (96, 2) :  None :     -0.6758402788276372 :  None : False : False :  Reals
#      (97, 1) :  None :     -0.5991862604582318 :  None : False : False :  Reals
#      (97, 2) :  None :     -0.7572922750775097 :  None : False : False :  Reals
#      (98, 1) :  None :     -0.6476435857588116 :  None : False : False :  Reals
#      (98, 2) :  None :     -0.7161188347651082 :  None : False : False :  Reals
#      (99, 1) :  None :    -0.45742378677992296 :  None : False : False :  Reals
#      (99, 2) :  None :    -0.47372930274185077 :  None : False : False :  Reals
#     (100, 1) :  None :                       0 :  None :  True :  True :  Reals
#     (100, 2) :  None :                       0 :  None :  True :  True :  Reals

# %% [markdown]
# # Animation

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as ani
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
from IPython.display import HTML

# Create the figure and subplots for XY, XZ, YZ planes, and a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')  # 3D plot

def plot_pendulum(i, m):  
    # Clear previous plots
    ax.clear()
    
    # Set limits and titles for each axis
    lim = 0.2
    ax.set_xlim([-lim, lim])
    ax.set_ylim([-lim, lim])
    ax.set_zlim([-lim, lim])
    ax.set_xlabel('X-axis', color='red')
    ax.set_ylabel('Y-axis', color='blue')
    ax.set_zlabel('Z-axis', color='green')
    ax.grid(True)

    # Calculate positions for the pendulum
    L1bottomx = m.X0.value + m.len[1] * np.cos(m.q[i,1].value)
    L1bottomy = m.Y0.value - m.len[1] * np.sin(m.q[i,1].value)
    L1bottomz = m.Z0.value

    L2bottomx = L1bottomx + m.len[2] * np.sin(m.q[i,1].value) * np.sin(m.q[i,2].value)
    L2bottomy = L1bottomy + m.len[2] * np.sin(m.q[i,1].value) * np.cos(m.q[i,2].value)
    L2bottomz = L1bottomz + m.len[2] * np.cos(m.q[i,2].value)

    # Plot in 3D
    ax.plot([m.X0.value, L1bottomx], [m.Y0.value, L1bottomy], [m.Z0.value, L1bottomz], color='xkcd:blue')
    ax.plot([L1bottomx, L2bottomx], [L1bottomy, L2bottomy], [L1bottomz, L2bottomz], color='xkcd:red')

# Update function for the animation
update = lambda i: plot_pendulum(i, m)

# Create animation
animate = ani.FuncAnimation(fig, update, range(1,N+1), interval=50, repeat=True)

# Embed the animation in the notebook
HTML(animate.to_html5_video())
# Out:
# <video width="640" height="480" controls autoplay loop>
#   <source type="video/mp4" src="...
